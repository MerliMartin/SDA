# %%
#Load dataset
import numpy as np
import pandas as pd
from sklearn.datasets import load_wine  # Classification

# %%
data = load_wine(as_frame=True)
df = data.data
df["y"] = data.target
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  y
# ...

# %%
df.T
# Out:
#                                   0        1        2        3       4    \
# alcohol                         14.23    13.20    13.16    14.37   13.24
# malic_acid                       1.71     1.78     2.36     1.95    2.59
# ash                              2.43     2.14     2.67     2.50    2.87
# alcalinity_of_ash               15.60    11.20    18.60    16.80   21.00
# magnesium                      127.00   100.00   101.00   113.00  118.00
# total_phenols                    2.80     2.65     2.80     3.85    2.80
# flavanoids                       3.06     2.76     3.24     3.49    2.69
# nonflavanoid_phenols             0.28     0.26     0.30     0.24    0.39
# proanthocyanins                  2.29     1.28     2.81     2.18    1.82
# color_intensity                  5.64     4.38     5.68     7.80    4.32
# hue                              1.04     1.05     1.03     0.86    1.04
# od280/od315_of_diluted_wines     3.92     3.40     3.17     3.45    2.93
# ...

# %%
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %% [markdown]
# 0. How will you classify the given dataset?
#     - Multi-class classification. In this dataset we have 3 classes, it means we have 3 types of wine.
# 1. What does the description tell you about the data?
#     - One thing is Average percentage of alcohol in wines is 13.050000%
# 2. Which feature have the most outliers?
#     -
# 3. What is the distribution of classes? (i.e. how many wines belong to each class)
#     -

# %%
df.columns
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline', 'y'],
#       dtype='object')

# %% [markdown]
# - Exploratory Data Analysis (EDA)
#
# 1. Visualizing distributions
#     - A. Class counting (Categorical data): bar plot / catplot
#     - B. Visualizing statistical parameters: boxplot
#     - C. Visualizing numerical distributions: histplots, kde
# 2. Exploring Relationships amongst features:
#     - A. BI-variate (x1, x2)
#     - B. Multi-variate (x1, x2, x3, ...)

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.12.1'

# %%
# !python.exe -m pip install --upgrade pip

# %%
# !pip install seaborn -U

# %%
sns.boxplot(
    df[["ash", "malic_acid"]],
    orient="h",
    color="teal"
).set(title="Distribution of ash & malic acid values")
# Out:
# [Text(0.5, 1.0, 'Distribution of ash & malic acid values')]

# %%
sns.histplot(
    df,
    x="malic_acid"
)
# Out:
# <AxesSubplot:xlabel='malic_acid', ylabel='Count'>

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  y
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df["ash"], vert=False)
plt.title("Distribution of  ash values")
# Out:
# Text(0.5, 1.0, 'Distribution of  ash values')

# %%
df.groupby("y").count().reset_index()
# Out:
#    y  alcohol  malic_acid  ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0  0       59          59   59                 59         59             59
# 1  1       71          71   71                 71         71             71
# 2  2       48          48   48                 48         48             48
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity  hue  \
# 0          59                    59               59               59   59
# 1          71                    71               71               71   71
# 2          48                    48               48               48   48
#
#    od280/od315_of_diluted_wines  proline
# 0                            59       59
# 1                            71       71
# 2                            48       48

# %%
sns.countplot(
    df,
    x="y"
)
# Out:
# <AxesSubplot:xlabel='y', ylabel='count'>

# %% [markdown]
# - Count frequencies for each class

# %%
n0 = len(df[df.y == 0])
n1 = len(df[df.y == 1])
n2 = len(df[df.y == 2])

# %%
df.y.unique()
# Out:
# array([0, 1, 2])

# %%
class_labels = df.y.unique()
class_freq = [len(df[df.y == x]) for x in class_labels]

plt.bar(x=class_labels, height=class_freq)
plt.title("Frequencies of Wine Classes")
# Out:
# Text(0.5, 1.0, 'Frequencies of Wine Classes')

# %%
sns.countplot(
    df,
    x="y"
)
# Out:
# <AxesSubplot:xlabel='y', ylabel='count'>
